# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('voice.csv')
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
data.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
data.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
print('shape of data:', data.shape)
print('Total number of labels: {}'.format(data.shape[0]))
print('Total number of men: {}'.format(data[data.label=='male'].shape[0]))
print('Total number of Females: {}'.format(data[data.label=='female'].shape[0]))
# Out:
# shape of data: (3168, 21)
# Total number of labels: 3168
# Total number of men: 1584
# Total number of Females: 1584

# %%
x = data.iloc[:,:-1]
print(data.shape)
print(x.shape)
# Out:
# (3168, 21)
# (3168, 20)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y = data.iloc[:,-1]
gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
svc_model = SVC()
svc_model.fit(x_train,y_train)
y_pred = svc_model.predict(x_test)

# %%
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.9737118822292324

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[458  13]
#  [ 12 468]]

# %%
from sklearn.model_selection import GridSearchCV

# %%
p_grid = {'c':[0.1,1,10,100],'d':[1,0.1,0.01,0.001]}

# %%
grid = GridSearchCV(SVC(),p_grid,refit=True,verbose=2)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [36], in <cell line: 2>()
#       1 grid = GridSearchCV(SVC(),p_grid,refit=True,verbose=2)
# ----> 2 grid.fit(x_train,y_train)
#
# File F:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# ...

# %%
grid_pred = grid.predict(x_test)
# Calculate Accuracy, confusion matrix and classification report
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 grid_pred = grid.predict(x_test)
#
# File F:\Anaconda\lib\site-packages\sklearn\utils\metaestimators.py:113, in _AvailableIfDescriptor.__get__.<locals>.<lambda>(*args, **kwargs)
#     110         raise attr_err
#     112     # lambda, but not partial, allows help() to work with update_wrapper
# --> 113     out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114 else:
#     116     def fn(*args, **kwargs):
#
# File F:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py:520, in BaseSearchCV.predict(self, X)
#     501 @available_if(_estimator_has("predict"))
#     502 def predict(self, X):
#     503     """Call predict on the estimator with the best found parameters.
#     504
# ...
